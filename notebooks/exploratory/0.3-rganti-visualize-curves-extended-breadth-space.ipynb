# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'svg'
import sys
import pickle
import numpy as np
np.set_printoptions(suppress=True)
import matplotlib.pyplot as plt
import seaborn as sns
from src.visualization.visualize_fitness import InjectionKlDistance, ProcessProtocolData, EnsembleProcessProtocolData
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Multiple Trials

# %%
path = "../../data/raw/extended_breadth_multiple_trials/Trials_dr_0.1_muij_0.05_bins_7/"
protocol_data = EnsembleProcessProtocolData(path)
# protocol_data.process_trial_statistics()
protocol_data.load_arrays()
# Out:
# Processing Sigma_1 = 3.0
# len(p0_mean) = 7
# Processing Sigma_1 = 2.3
# len(p0_mean) = 7
# Processing Sigma_1 = 2.1
# len(p0_mean) = 7
# Processing Sigma_1 = 1.93
# len(p0_mean) = 7
# Processing Sigma_1 = 1.7
# len(p0_mean) = 7
# Processing Sigma_1 = 1.3
# len(p0_mean) = 7
# Processing Sigma_1 = 1.0
# len(p0_mean) = 7
# Processing Sigma_1 = 0.7
# len(p0_mean) = 7

# %%
protocol_data.plot_protocols()

# %%
protocol_data.plot_survival_fraction()

# %%
path = "../../data/raw/extended_breadth_multiple_trials/Trials_dr_0.05_muij_0.05_bins_9/"
protocol_data = EnsembleProcessProtocolData(path)
# protocol_data.process_trial_statistics()
protocol_data.load_arrays()
# Out:
# Processing Sigma_1 = 2.0
# len(p0_mean) = 9
# Processing Sigma_1 = 1.7
# len(p0_mean) = 9
# Processing Sigma_1 = 1.3
# len(p0_mean) = 9
# Processing Sigma_1 = 1.2
# len(p0_mean) = 9
# Processing Sigma_1 = 1.0
# len(p0_mean) = 9
# Processing Sigma_1 = 0.7
# len(p0_mean) = 9
# Processing Sigma_1 = 0.3
# len(p0_mean) = 9

# %%
protocol_data.plot_protocols()

# %%
protocol_data.plot_survival_fraction()
plt.xlim(1.0, 5)
# Out:
# (1.0, 5)

# %%
path = "../../data/raw/extended_breadth_multiple_trials/Trials_dr_0.05_muij_0.05_bins_11/"
protocol_data = EnsembleProcessProtocolData(path)
# protocol_data.process_trial_statistics()
protocol_data.load_arrays()
# Out:
# Processing Sigma_1 = 2.0
# len(p0_mean) = 11
# Processing Sigma_1 = 1.7
# len(p0_mean) = 11
# Processing Sigma_1 = 1.6
# len(p0_mean) = 11
# Processing Sigma_1 = 1.5
# len(p0_mean) = 11
# Processing Sigma_1 = 1.3
# len(p0_mean) = 11
# Processing Sigma_1 = 1.0
# len(p0_mean) = 11
# Processing Sigma_1 = 0.7
# len(p0_mean) = 11
# Processing Sigma_1 = 0.3
# len(p0_mean) = 11

# %%
protocol_data.plot_protocols()

# %%
protocol_data.plot_survival_fraction()
plt.xlim(1.5, 5)
# Out:
# (1.5, 5)

# %%
ls /nfs/pool002/users/rganti
# Out:
# Optimal_Protocols_bnabs_pool002/

# %%
path = "/nfs/pool002/users/rganti/Optimal_Protocols_bnabs_pool002/data/raw/Trials_dr_0.02_muij_0.05_bins_15/"
protocol_data = EnsembleProcessProtocolData(path)
# protocol_data.process_trial_statistics()
protocol_data.load_arrays()

# %%
protocol_data.plot_protocols(set_sns=True)
plt.legend()

# %%
protocol_data.plot_survival_fraction()

# %%
p0 = np.loadtxt(path + "Sigma_0.8/Trial_0/event_prob")
plt.plot(range(1,16),p0, marker='o')
plt.ylabel("$P_{0}$")
plt.xlabel("Breadth States")
# Out:
# Text(0.5,0,'Breadth States')

# %% [markdown]
# # Test Calculations

# %%
path = "../../data/raw/extended_breadth_space/test_dr_0.1_muij_0.05_bins_7/"
protocol_data = ProcessProtocolData(path)
protocol_data.load_arrays()
# Out:
# Processing sigma_1 = 0.1
# len(p0_mean) = 7
# Processing sigma_1 = 0.13895
# len(p0_mean) = 7
# Processing sigma_1 = 0.19307
# len(p0_mean) = 7
# Processing sigma_1 = 0.26827
# len(p0_mean) = 7
# Processing sigma_1 = 0.372759
# len(p0_mean) = 7
# Processing sigma_1 = 0.517947
# len(p0_mean) = 7
# Processing sigma_1 = 0.719686
# len(p0_mean) = 7
# Processing sigma_1 = 1.0
# len(p0_mean) = 7
# Processing sigma_1 = 1.389495
# len(p0_mean) = 7
# Processing sigma_1 = 1.930698
# len(p0_mean) = 7
# Processing sigma_1 = 2.682696
# len(p0_mean) = 7
# Processing sigma_1 = 3.727594
# len(p0_mean) = 7
# Processing sigma_1 = 5.179475
# len(p0_mean) = 7
# Processing sigma_1 = 7.196857
# len(p0_mean) = 7
# Processing sigma_1 = 10.0
# len(p0_mean) = 7

# %%
protocol_data.plot_protocols()

# %%
path = "../../data/raw/extended_breadth_space/test_dr_0.1_muij_0.1_bins_7/"
protocol_data = ProcessProtocolData(path)
protocol_data.load_arrays()
# Out:
# Processing sigma_1 = 0.1
# len(p0_mean) = 7
# Processing sigma_1 = 0.13895
# len(p0_mean) = 7
# Processing sigma_1 = 0.19307
# len(p0_mean) = 7
# Processing sigma_1 = 0.26827
# len(p0_mean) = 7
# Processing sigma_1 = 0.372759
# len(p0_mean) = 7
# Processing sigma_1 = 0.517947
# len(p0_mean) = 7
# Processing sigma_1 = 0.719686
# len(p0_mean) = 7
# Processing sigma_1 = 1.0
# len(p0_mean) = 7
# Processing sigma_1 = 1.389495
# len(p0_mean) = 7
# Processing sigma_1 = 1.930698
# len(p0_mean) = 7
# Processing sigma_1 = 2.682696
# len(p0_mean) = 7
# Processing sigma_1 = 3.727594
# len(p0_mean) = 7
# Processing sigma_1 = 5.179475
# len(p0_mean) = 7
# Processing sigma_1 = 7.196857
# len(p0_mean) = 7
# Processing sigma_1 = 10.0
# len(p0_mean) = 7

# %%
protocol_data.plot_protocols()

# %%
path = "../../data/raw/extended_breadth_space/test_dr_0.05_muij_0.05_bins_9/"
protocol_data = ProcessProtocolData(path)
protocol_data.load_arrays()
# Out:
# Processing sigma_1 = 2.0
# len(p0_mean) = 9
# Processing sigma_1 = 1.7
# len(p0_mean) = 9
# Processing sigma_1 = 1.3
# len(p0_mean) = 9
# Processing sigma_1 = 1.2
# len(p0_mean) = 9
# Processing sigma_1 = 1.0
# len(p0_mean) = 9

# %%
protocol_data.plot_protocols()

# %%
path = "../../data/raw/extended_breadth_space/test_dr_0.05_muij_0.05_bins_11/"
protocol_data = ProcessProtocolData(path)
protocol_data.load_arrays()
# Out:
# Processing sigma_1 = 2.0
# len(p0_mean) = 11
# Processing sigma_1 = 1.7
# len(p0_mean) = 11
# Processing sigma_1 = 1.5
# len(p0_mean) = 11
# Processing sigma_1 = 1.3
# len(p0_mean) = 11
# Processing sigma_1 = 1.0
# len(p0_mean) = 11

# %%
protocol_data.plot_protocols()

# %%
path = "../../data/raw/extended_breadth_space/test_dr_0.02_muij_0.05_bins_15/"
protocol_data = ProcessProtocolData(path)
protocol_data.load_arrays()
# Out:
# Processing sigma_1 = 2.0
# len(p0_mean) = 15
# Processing sigma_1 = 1.5
# len(p0_mean) = 15
# Processing sigma_1 = 1.3
# len(p0_mean) = 15
# Processing sigma_1 = 1.2
# len(p0_mean) = 15
# Processing sigma_1 = 1.1
# len(p0_mean) = 15
# Processing sigma_1 = 1.0
# len(p0_mean) = 15
# Processing sigma_1 = 0.9
# len(p0_mean) = 15
# Processing sigma_1 = 0.8
# len(p0_mean) = 15
# Processing sigma_1 = 0.7
# len(p0_mean) = 15
# Processing sigma_1 = 0.3
# len(p0_mean) = 15
# /home/rganti/Optimal_Protocols_bnAbs/src/visualization/visualize_fitness.py:99: RuntimeWarning: invalid value encountered in divide
#   p1.append(np.loadtxt(path + "n_ave") / np.sum(np.loadtxt(path + "n_ave")))

# %%
protocol_data.plot_protocols()

# %%
path = "../../data/raw/extended_breadth_space/test_dr_0.05_muij_0.05_bins_9/"
protocol_data = ProcessProtocolData(path)
protocol_data.load_arrays()
# Out:
# Processing sigma_1 = 2.0
# len(p0_mean) = 9
# Processing sigma_1 = 1.7
# len(p0_mean) = 9
# Processing sigma_1 = 1.3
# len(p0_mean) = 9
# Processing sigma_1 = 1.2
# len(p0_mean) = 9
# Processing sigma_1 = 1.0
# len(p0_mean) = 9

# %%
protocol_data.plot_protocols()

# %%
path = "../../data/raw/extended_breadth_space/bins_9_prime_boost/"
protocol_data = ProcessProtocolData(path, sigma_1_range[::-1])
protocol_data.load_arrays()
# Out:
# Processing sigma_1 = 1.8
# len(p0_mean) = 9
# Processing sigma_1 = 1.5
# len(p0_mean) = 9
# Processing sigma_1 = 1.4
# len(p0_mean) = 9
# Processing sigma_1 = 1.3
# len(p0_mean) = 9
# Processing sigma_1 = 1.2
# len(p0_mean) = 9
# Processing sigma_1 = 1.0
# len(p0_mean) = 9
# Processing sigma_1 = 0.5
# len(p0_mean) = 9
# Processing sigma_1 = 0.3
# len(p0_mean) = 9

# %%
sns.set_palette(sns.color_palette("hls", len(protocol_data.kl1_array)))
for i in range(len(protocol_data.kl1_array)):
    plt.errorbar(protocol_data.kl2_matrix[i], protocol_data.mean_bnab_array[i], marker='o', 
                 label='$D(p_{0} || f_{1}) = ' + '%.2f' % protocol_data.kl1_array[i] + ', \\sigma_{1} = %.2f' % protocol_data.sigma_1_range[i] + ' $')    

plt.legend(bbox_to_anchor=(1.05, 1.00))
plt.xlabel("$D(p_{1} || f_{2})$")
plt.ylabel("Number of bnAbs/GC")
plt.title("Prime and Boost Protocols")
# Out:
# Text(0.5,1,'Prime and Boost Protocols')

# %%
sigma_1_range = [1.2, 1.3, 1.4, 1.6, 1.8, 1.9, 2.0, 2.1, 2.2, 2.3, 2.4, 2.5, 3.0, 3.5, 4.0]

# %%
path = "../../data/raw/extended_breadth_space/bins_9_prime_boost_dr_0.08/"
protocol_data = ProcessProtocolData(path, sigma_1_range[::-1])
protocol_data.load_arrays()
# Out:
# Processing sigma_1 = 4.0
# len(p0_mean) = 9
# Processing sigma_1 = 3.5
# len(p0_mean) = 9
# Processing sigma_1 = 3.0
# len(p0_mean) = 9
# Processing sigma_1 = 2.5
# len(p0_mean) = 9
# Processing sigma_1 = 2.4
# len(p0_mean) = 9
# Processing sigma_1 = 2.3
# len(p0_mean) = 9
# Processing sigma_1 = 2.2
# len(p0_mean) = 9
# Processing sigma_1 = 2.1
# len(p0_mean) = 9
# Processing sigma_1 = 2.0
# len(p0_mean) = 9
# Processing sigma_1 = 1.9
# len(p0_mean) = 9
# Processing sigma_1 = 1.8
# len(p0_mean) = 9
# Processing sigma_1 = 1.6
# len(p0_mean) = 9
# Processing sigma_1 = 1.4
# len(p0_mean) = 9
# Processing sigma_1 = 1.3
# len(p0_mean) = 9
# Processing sigma_1 = 1.2
# len(p0_mean) = 9

# %%
sns.set_palette(sns.color_palette("hls", len(protocol_data.kl1_array)))
for i in range(len(protocol_data.kl1_array)):
    plt.errorbar(protocol_data.kl2_matrix[i], protocol_data.mean_bnab_array[i], marker='o', 
                 label='$D(p_{0} || f_{1}) = ' + '%.2f' % protocol_data.kl1_array[i] + ', \\sigma_{1} = %.2f' % protocol_data.sigma_1_range[i] + ' $')    

plt.legend(bbox_to_anchor=(1.05, 1.00))
plt.xlabel("$D(p_{1} || f_{2})$")
plt.ylabel("Number of bnAbs/GC")
plt.title("Prime and Boost Protocols")
# Out:
# Text(0.5,1,'Prime and Boost Protocols')

# %%
sigma_1_range = [2.4, 2.5, 2.6, 2.7, 2.8, 3.0, 3.2, 3.4]

# %%
path = "../../data/raw/extended_breadth_space/bins_9_prime_boost_dr_0.09/"
protocol_data = ProcessProtocolData(path, sigma_1_range[::-1])
protocol_data.load_arrays()
# Out:
# Processing sigma_1 = 3.4
# len(p0_mean) = 9
# Processing sigma_1 = 3.2
# len(p0_mean) = 9
# Processing sigma_1 = 3.0
# len(p0_mean) = 9
# Processing sigma_1 = 2.8
# len(p0_mean) = 9
# Processing sigma_1 = 2.7
# len(p0_mean) = 9
# Processing sigma_1 = 2.6
# len(p0_mean) = 9
# Processing sigma_1 = 2.5
# len(p0_mean) = 9
# Processing sigma_1 = 2.4
# len(p0_mean) = 9

# %%
sns.set_palette(sns.color_palette("hls", len(protocol_data.kl1_array)))
for i in range(len(protocol_data.kl1_array)):
    plt.errorbar(protocol_data.kl2_matrix[i], protocol_data.mean_bnab_array[i], marker='o', 
                 label='$D(p_{0} || f_{1}) = ' + '%.2f' % protocol_data.kl1_array[i] + ', \\sigma_{1} = %.2f' % protocol_data.sigma_1_range[i] + ' $')    

plt.legend(bbox_to_anchor=(1.05, 1.00))
plt.xlabel("$D(p_{1} || f_{2})$")
plt.ylabel("Number of bnAbs/GC")
plt.title("Prime and Boost Protocols")
# Out:
# Text(0.5,1,'Prime and Boost Protocols')

# %%
sigma_1_range = np.logspace(1.0, -1.0, num=15)
# sigma_1_range = [1.8, 2.0, 2.3, 2.5, 2.7]

# %%
path = "../../data/raw/extended_breadth_space/test_dr_0.05_muij_0.05_bins_9/"
protocol_data = ProcessProtocolData(path)
protocol_data.load_arrays()
# Out:
# Processing sigma_1 = 2.0
# len(p0_mean) = 9
# Processing sigma_1 = 1.7
# len(p0_mean) = 9
# Processing sigma_1 = 1.3
# len(p0_mean) = 9
# Processing sigma_1 = 1.2
# len(p0_mean) = 9
# Processing sigma_1 = 1.0
# len(p0_mean) = 9

# %%
protocol_data.plot_protocols()

# %%
path = "../../data/raw/extended_breadth_space/test"
protocol_data = ProcessProtocolData(path)
protocol_data.load_arrays()
# Out:
# Processing sigma_1 = 0.1
# len(p0_mean) = 7
# Processing sigma_1 = 0.13895
# len(p0_mean) = 7
# Processing sigma_1 = 0.19307
# len(p0_mean) = 7
# Processing sigma_1 = 0.26827
# len(p0_mean) = 7
# Processing sigma_1 = 0.372759
# len(p0_mean) = 7
# Processing sigma_1 = 0.517947
# len(p0_mean) = 7
# Processing sigma_1 = 0.719686
# len(p0_mean) = 7
# Processing sigma_1 = 1.0
# len(p0_mean) = 7
# Processing sigma_1 = 1.389495
# len(p0_mean) = 7
# Processing sigma_1 = 1.930698
# len(p0_mean) = 7
# Processing sigma_1 = 2.682696
# len(p0_mean) = 7
# Processing sigma_1 = 3.727594
# len(p0_mean) = 7
# Processing sigma_1 = 5.179475
# len(p0_mean) = 7
# Processing sigma_1 = 7.196857
# len(p0_mean) = 7
# Processing sigma_1 = 10.0
# len(p0_mean) = 7

# %%
protocol_data.plot_protocols()
