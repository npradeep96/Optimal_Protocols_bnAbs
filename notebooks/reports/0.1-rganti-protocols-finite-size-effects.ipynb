# %% [markdown]
# # Data:
# ../../data/raw/extended_breadth_multiple_trials/

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'svg'
import sys
import pickle
import numpy as np
import seaborn as sns
np.set_printoptions(suppress=True)
import matplotlib.pyplot as plt
import seaborn as sns
from src.visualization.visualize_fitness import InjectionKlDistance, ProcessProtocolData, EnsembleProcessProtocolData
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
relative_path = "../../data/raw/extended_breadth_multiple_trials/"
path_array = [relative_path + 'Trials_dr_0.1_muij_0.05_bins_7/', relative_path + 'Trials_dr_0.05_muij_0.05_bins_9/', 
             relative_path + 'Trials_dr_0.05_muij_0.05_bins_11/',
#               '/nfs/pool002/users/rganti/Optimal_Protocols_bnabs_pool002/data/raw/Trials_dr_0.02_muij_0.05_bins_15/',
              '/nfs/arupclab001/Optimal_Protocol_bnAbs_arupc_lab001/data/raw/Trials_dr_0.02_muij_0.05_bins_15/'
             ]

# %%
sns.set_palette(sns.color_palette("hls", 12))
plt.figure(figsize=(12,10))
for i in range(len(path_array)):
    plt.subplot(2,2,i+1)
    path = path_array[i]
    protocol_data = EnsembleProcessProtocolData(path)
    protocol_data.load_arrays()
    protocol_data.plot_protocols()
    plt.legend()

# %%
sns.set_palette(sns.color_palette("hls", 12))
plt.figure(figsize=(12,10))
for i in range(len(path_array)):
    plt.subplot(2,2,i+1)
    path = path_array[i]
    protocol_data = EnsembleProcessProtocolData(path)
    protocol_data.load_arrays()
    protocol_data.plot_survival_fraction()
    plt.legend()
